# %%
import transformers

from transformers import AutoTokenizer as AT

# %%
tokenizer = AT.from_pretrained("t5-small")

text = "That guy is the goat. If you know you know"

token_info = tokenizer(text, return_tensors = "pt")

id_tensor = token_info['input_ids']

attention_mask = token_info['attention_mask']

tokenizer.vocab_size

id_tensor
# Out:
# tensor([[  466,  4024,    19,     8, 18174,     5,   156,    25,   214,    25,
#            214,     1]])
